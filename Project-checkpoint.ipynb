# %% [markdown]
# ## Exploratory data analysis of boston housing

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %%
# import pickle as pkl--> ypu need this library when you download your dataset as .pkl format

# %%
boston = pd.read_csv('D:\Projects DA\Boston house prediction\HousingData.csv')

# %%
boston.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87   NaN  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87   NaN  0.524  6.004   85.9  6.5921    5  311     15.2
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# ...

# %%
boston.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
boston.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
boston.duplicated().sum()
# Out:
# 0

# %%
boston_desc = boston.describe()
boston_desc.loc['mean']
# Out:
# CRIM         3.611874
# ZN          11.211934
# INDUS       11.083992
# CHAS         0.069959
# NOX          0.554695
# RM           6.284634
# AGE         68.518519
# DIS          3.795043
# RAD          9.549407
# TAX        408.237154
# PTRATIO     18.455534
# B          356.674032
# LSTAT       12.715432
# MEDV        22.532806
# Name: mean, dtype: float64

# %%
boston_desc.loc['mean'].plot.bar()
# Out:
# <AxesSubplot:>

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
len(plt.style.available)
# Out:
# 28

# %%
plt.figure(figsize=(7,5))
for style in plt.style.available:
    plt.style.use(style)
    boston_desc.loc['mean'].plot.bar()
    plt.title(style)
    plt.savefig('\plots' + style + '.png')

# %%
plt.figure(figsize=(7,5))
plt.style.use('ggplot')
boston_desc.loc['mean'].plot.bar()
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(boston)

# %%
sns.pairplot(boston.iloc[:, np.hstack(([0], range(1,7)))], diag_kind='kde')

# %% [markdown]
# ## Distribution Plots

# %%
rows = 2
columns = 7
fig, ax = plt.subplots(nrows = rows, ncols = columns, figsize=(16,4))
col = boston.columns
index = 0
for i in range(rows):
    for j in range(columns):
        sns.displot(boston[col[index]], ax = ax[i][j])
        index = index+1 
        
plt.tight_layout()
# Out:
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2211: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2211: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2211: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# # Scatter Plot

# %% [markdown]
# ## Plotting MEDV with other columns

# %%
rows = 2
cols = 7
fig, ax = plt.subplots(rows, cols, figsize=(16,4))
col = boston.columns
index = 0
for i in range(rows):
    for j in range(cols):
        sns.scatterplot(x = 'MEDV', y =col[index], data = boston, ax = ax[i][j])
        index = index+1 
        
plt.tight_layout() 
# if the no of rooms increase the price will also increase

# %% [markdown]
# # Heatmap

# %%
corrmat = boston.corr()   # correlation of the columns 
corrmat
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.191178  0.401863 -0.054355  0.417130 -0.219150  0.354342
# ZN      -0.191178  1.000000 -0.531871 -0.037229 -0.513704  0.320800 -0.563801
# INDUS    0.401863 -0.531871  1.000000  0.059859  0.764866 -0.390234  0.638431
# CHAS    -0.054355 -0.037229  0.059859  1.000000  0.075097  0.104885  0.078831
# NOX      0.417130 -0.513704  0.764866  0.075097  1.000000 -0.302188  0.731548
# RM      -0.219150  0.320800 -0.390234  0.104885 -0.302188  1.000000 -0.247337
# AGE      0.354342 -0.563801  0.638431  0.078831  0.731548 -0.247337  1.000000
# DIS     -0.374166  0.656739 -0.711709 -0.093971 -0.769230  0.205246 -0.744844
# RAD      0.624765 -0.310919  0.604533  0.001468  0.611441 -0.209847  0.458349
# TAX      0.580595 -0.312371  0.731055 -0.032304  0.668023 -0.292048  0.509114
# PTRATIO  0.281110 -0.414046  0.390954 -0.111304  0.188933 -0.355501  0.269226
# ...

# %%
corrmat.shape
# Out:
# (14, 14)

# %%
fig, ax = plt.subplots(figsize=(7,5))   # whittesh side means +ve correlation
sns.heatmap(corrmat, annot = True, cmap='hot')  # reddish side means -ve correlation
# Out:
# <AxesSubplot:>

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.5.2'

# %% [markdown]
# ## Correlation Feature Selection

# %%
corrmat.index
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
def getcorrelated(corrdata, threshold):
    feature = []
    values = []
    
    for i, index in enumerate(corrdata.index): 
        if abs(corrdata[index])> threshold:
            feature.append(index)
            values.append(corrdata[index])
        
    df = pd.DataFrame(data = values, index = feature, columns=['corr value'])
    return df

# %%
threshold = 0.5
corr_df = getcorrelated(corrmat['MEDV'], threshold)

# %%
corr_df
# Out:
#          corr value
# RM         0.695360
# PTRATIO   -0.507787
# LSTAT     -0.735822
# MEDV       1.000000

# %% [markdown]
# # Heatmap and Pairplot of correlated data

# %%
correlated = boston[corr_df.index]
correlated.head()
# Out:
#       RM  PTRATIO  LSTAT  MEDV
# 0  6.575     15.3   4.98  24.0
# 1  6.421     17.8   9.14  21.6
# 2  7.185     17.8   4.03  34.7
# 3  6.998     18.7   2.94  33.4
# 4  7.147     18.7    NaN  36.2

# %%
sns.pairplot(correlated)
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(4,4))
sns.heatmap(correlated.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Box and Rel plots

# %%
# CHAS means charles river if the house is nearby CHAS river then the price the house of the house is more and vice- versa
plt.figure(figsize=(6,5))    
sns.boxplot(y = 'MEDV', x = 'CHAS', data = boston)
# Out:
# <AxesSubplot:xlabel='CHAS', ylabel='MEDV'>

# %%
plt.figure(figsize=(6,5))    
sns.scatterplot(y = 'MEDV', x = 'CHAS', data = boston)
# Out:
# <AxesSubplot:xlabel='CHAS', ylabel='MEDV'>

# %%
sns.relplot(x = 'RM', y = 'MEDV', data = boston, hue = 'CHAS') # black dot shows that less house are near CHAS river

# %%
sns.relplot(x = 'RM', y = 'MEDV', data = boston, col = 'CHAS')

# %% [markdown]
# # Joint plots

# %% [markdown]
# #### when dealing with the data , first thing we need to sense how variables are distributed

# %%
sns.jointplot(x = boston['RM'], y = boston['MEDV'])

# %%
sns.jointplot(x = boston['RM'], y = boston['MEDV'], kind = 'hex') # This shows that an avg price of house is 20 dollars

# %%
g = sns.jointplot(x = boston['RM'], y = boston['MEDV'], kind = 'kde', color = 'm')
g.plot_joint(plt.scatter, c = 'r', marker = '+')

# %%
fig, ax = plt.subplots(figsize = (6,6))
cmap = sns.cubehelix_palette(as_cmap=True, dark = 0, light=1, reverse=True)
sns.kdeplot(boston['RM'], boston['MEDV'], cmap = cmap, n_levels = 60, shade = True)
# Out:
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='RM', ylabel='MEDV'>

# %% [markdown]
# ## Linear Regression and Relationship

# %% [markdown]
# ###### implot()
# ###### regplot()

# %%
plt.figure(figsize=(6,5))
sns.regplot(x = 'RM', y = 'MEDV', data = boston, color = 'm')
# Out:
# <AxesSubplot:xlabel='RM', ylabel='MEDV'>

# %%
plt.figure(figsize=(6,5))
sns.lmplot(x = 'CHAS', y = 'MEDV', data = boston, palette='hot')

# %%
plt.figure(figsize=(6,5))
sns.lmplot(x = 'RM', y = 'MEDV', data = boston, hue = 'CHAS')

# %%
plt.figure(figsize=(6,5))
sns.lmplot(x = 'CHAS', y = 'MEDV', data = boston, x_estimator=np.mean)
